# %%
from gbeampro.examples import focusing_to_crystal
# Out:
# GaussBeam (Initial, collimated)
# ----------------------------------
#   z : 0.000 mm
#   n : 1.0000
#   q : 13.949 -11810.482i
#   w : 2.000 mm
#   R : 10000.000 m
#   theta : 0.169 mrad
# ----------------------------------
#
# GaussBeam (after collimation by lens2)
# ----------------------------------
#   z : 356.000 mm
#   n : 1.0000
#   q : 2556.344 -3220.892i
#   w : 1.333 mm
#   R : 6.615 m
#   theta : 0.254 mrad
# ----------------------------------
#
# Beam waists in z-range [0.00, 356.00] mm
# --------------------------------------------------
# No.0:
#   Waist location, z  : 0.0000 mm
#   Refractive index, n  : 1.0000
#   Waist spot diamter, 2*w0 : 4000.0 µm
#   Confocal parameter (2*Rayleigh range) : 23621.00 mm
#   2.84 * Confocal parameter : 67083.63 mm
# No.1:
#   Waist location, z  : 154.2000 mm
#   Refractive index, n  : 1.6043
#   Waist spot diamter, 2*w0 : 50.8 µm
#   Confocal parameter (2*Rayleigh range) : 6.11 mm
#   2.84 * Confocal parameter : 17.36 mm

# %%
from gbeampro.examples import telescope_collimation
# Out:
# GaussBeam (Initial, collimated)
# ----------------------------------
#   z : 0.000 mm
#   n : 1.0000
#   q : 13.949 -11810.482i
#   w : 2.000 mm
#   R : 10000.000 m
#   theta : 0.169 mrad
# ----------------------------------
#
# GaussBeam (after collimation by lens2)
# ----------------------------------
#   z : 450.000 mm
#   n : 1.0000
#   q : 428.487 -2952.621i
#   w : 1.010 mm
#   R : 20.774 m
#   theta : 0.335 mrad
# ----------------------------------
#
# Beam waists in z-range [0.00, 450.00] mm
# --------------------------------------------------
# No.0:
#   Waist location, z  : 0.0000 mm
#   Refractive index, n  : 1.0000
#   Waist spot diamter, 2*w0 : 4000.0 µm
#   Confocal parameter (2*Rayleigh range) : 23621.00 mm
#   2.84 * Confocal parameter : 67083.63 mm
# No.1:
#   Waist location, z  : 50.0000 mm
#   Refractive index, n  : 1.0000
#   Waist spot diamter, 2*w0 : 2000.1 µm
#   Confocal parameter (2*Rayleigh range) : 5905.79 mm
#   2.84 * Confocal parameter : 16772.45 mm
